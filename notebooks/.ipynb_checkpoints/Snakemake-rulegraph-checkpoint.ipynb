# %%
# Ping the ENCODE API and return data in JSON format
def fetch(url):
  headers = {'accept': 'application/json'}
  response = requests.get(url, headers=headers)
  data = response.json()
  return(data)

# %%
def get_exp_data(exp):
    url = "https://www.encodeproject.org/experiments/"+exp+"/?format=json"
    data = fetch(url)
    toReturn = []
    
    assay = data["assay_term_name"]
    try:
        biosample = data["biosample_ontology"]["term_name"]
        synonyms = ",".join(data["biosample_ontology"]["synonyms"])
    except:
        biosample = ""
        synonyms = ""
    try:
        target = data["target"]["label"]
    except:
        target = "Control"

    if target == "Control":
        controls = [data['control_type']]
    else:
        # get control / input experiment
        controls = []
        for ctrl in data["possible_controls"]:
            controls.append(ctrl["accession"])
        
    for x in data["files"]:
        try:
            acc = x["accession"]
        except:
            continue
        file_format = x["file_format"]
        if file_format == "fastq":
            output_type = x['output_type']
            if output_type == "reads":
                biorep = x['biological_replicates'][0]
                techrep = x["technical_replicates"][0]
                try:
                    url = x['cloud_metadata']['url']
                except:
                    continue
                read_length = x["read_length"]
                md5sum = x['md5sum']
                run_type = x['run_type']
                read_count = x['read_count']
                if run_type == "paired-ended":
                    read = x["paired_end"]
                else:
                    read = "1"

                status = x["status"]
                if status == "released":
                    toReturn.append([exp, acc, target, biosample, synonyms, biorep, techrep, read, read_length, run_type, read_count, url, md5sum, ",".join(controls)])
    return(toReturn)

# %%
exp_data = fetch(construct_url())

# %%
experiments = [x["accession"] for x in exp_data['@graph']]

# %%
print("There are {} experiments".format(len(experiments)))
# Out:
# There are 3204 experiments

# %%
# get_exp_data("ENCSR822CEA")

# %%
metadata = []
for i in tqdm.trange(len(experiments)):
    metadata.append(get_exp_data(experiments[i]))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3204/3204 [34:31<00:00,  1.55it/s]

# %%
def flatten(xss):
    return [x for xs in xss for x in xs]
    
df = pd.DataFrame(flatten(metadata), columns=["exp", "acc", "target", "biosample", "synonyms", "biorep", "techrep", "read", "read_length", "run_type", "read_count", "url", "md5sum", "controls"])

# %%
df.head()
# Out:
#            exp          acc    target biosample           synonyms  biorep  \
# 0  ENCSR959XNY  ENCFF655BEL      MED1     HepG2  HepG2 cell,Hep-G2       2
# 1  ENCSR959XNY  ENCFF920MZO      MED1     HepG2  HepG2 cell,Hep-G2       1
# 2  ENCSR577YCO  ENCFF075LHW  ARHGAP35     HepG2  HepG2 cell,Hep-G2       1
# 3  ENCSR577YCO  ENCFF504PYF  ARHGAP35     HepG2  HepG2 cell,Hep-G2       1
# 4  ENCSR577YCO  ENCFF574DSC  ARHGAP35     HepG2  HepG2 cell,Hep-G2       2
#
#   techrep read  read_length      run_type  read_count  \
# 0     2_1    1           75  single-ended    40474263
# 1     1_1    1           75  single-ended    38046079
# 2     1_2    1          100  single-ended    32210747
# 3     1_2    1          100  single-ended    32231636
# 4     2_2    1          100  single-ended    18968586
#
#                                                  url  \
# 0  https://encode-public.s3.amazonaws.com/2018/06...
# 1  https://encode-public.s3.amazonaws.com/2018/06...
# 2  https://encode-public.s3.amazonaws.com/2022/01...
# 3  https://encode-public.s3.amazonaws.com/2022/01...
# 4  https://encode-public.s3.amazonaws.com/2022/01...
#
#                              md5sum     controls
# 0  596f29273326f236d21e9dcfbc7bde44  ENCSR020QUJ
# 1  872871049ed39779348841c516e36311  ENCSR020QUJ
# 2  a42e339580b9832afb0357dabda8b648  ENCSR239QGH
# 3  dd750faa1dec4db3bb1f27a83674df2c  ENCSR239QGH
# 4  8f94a92a30e42ad4ee2d32a3b8b3cb78  ENCSR239QGH

# %%
df.to_csv("Metadata.txt", sep="\t", header=True, index=False)

# %%
# !cat Metadata.txt |  wc -l
# Out:
# 9852

# %%
control_experiments = list(set(flatten([_.split(",") for _ in df.controls.tolist()])))

# %%
len(control_experiments)
# Out:
# 1071

# %%
control_metadata = []
for i in tqdm.trange(len(control_experiments)):
    try:
        control_metadata.append(get_exp_data(control_experiments[i]))
    except:
        pass
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████| 1071/1071 [08:28<00:00,  2.11it/s]

# %%
control_df = pd.DataFrame(flatten(control_metadata), columns=["exp", "acc", "target", "biosample", "synonyms", "biorep", "techrep", "read", "read_length", "run_type", "read_count", "url", "md5sum", "controls"])

# %%
control_df.head()
# Out:
#            exp          acc   target              biosample  \
# 0  ENCSR501CEJ  ENCFF480KWL  Control                   K562
# 1  ENCSR501CEJ  ENCFF440JUL  Control                   K562
# 2  ENCSR631ESZ  ENCFF144AGB  Control  foreskin keratinocyte
# 3  ENCSR631ESZ  ENCFF699DOM  Control  foreskin keratinocyte
# 4  ENCSR631ESZ  ENCFF314CVE  Control  foreskin keratinocyte
#
#                       synonyms  biorep techrep read  read_length  \
# 0   K562 cell,K-562,K-562 cell       1     1_1    1          100
# 1   K562 cell,K-562,K-562 cell       1     1_1    2          100
# 2                                    1     1_1    1          101
# 3                                    1     1_1    2          101
# 4                                    2     2_1    1          101
#
#        run_type  read_count  \
# 0  paired-ended    40527474
# 1  paired-ended    40527474
# 2  paired-ended    53545193
# 3  paired-ended    53545193
# 4  paired-ended    55163711
#
#                                                  url  \
# 0  https://encode-public.s3.amazonaws.com/2019/01...
# 1  https://encode-public.s3.amazonaws.com/2019/01...
# 2  https://encode-public.s3.amazonaws.com/2016/12...
# 3  https://encode-public.s3.amazonaws.com/2016/12...
# 4  https://encode-public.s3.amazonaws.com/2016/12...
#
#                              md5sum       controls
# 0  2ed14357716c9c6984e253a203232b3f  input library
# 1  833b82da601d4bd440d036c355f46317  input library
# 2  12205cf8fe66fc7df336a89f014cba33  input library
# 3  522b0254a97c18e2878d4f253359919c  input library
# 4  946aa908c62e8c131f5ae7160c134001  input library

# %%
input_controls = control_df[control_df["controls"] == "input library"].exp.tolist()
wild_type_controls = control_df[control_df["controls"] == "wild type"].exp.tolist()

# %%
def get_matching_control(possible_controls):
    for exp in possible_controls.split(","):
        if exp in input_controls:
            return(exp)
    for exp in possible_controls.split(","):
        if exp in wild_type_controls:
            return(exp)
    return(None)

# %%
df.head()
# Out:
#            exp          acc    target biosample           synonyms  biorep  \
# 0  ENCSR959XNY  ENCFF655BEL      MED1     HepG2  HepG2 cell,Hep-G2       2
# 1  ENCSR959XNY  ENCFF920MZO      MED1     HepG2  HepG2 cell,Hep-G2       1
# 2  ENCSR577YCO  ENCFF075LHW  ARHGAP35     HepG2  HepG2 cell,Hep-G2       1
# 3  ENCSR577YCO  ENCFF504PYF  ARHGAP35     HepG2  HepG2 cell,Hep-G2       1
# 4  ENCSR577YCO  ENCFF574DSC  ARHGAP35     HepG2  HepG2 cell,Hep-G2       2
#
#   techrep read  read_length      run_type  read_count  \
# 0     2_1    1           75  single-ended    40474263
# 1     1_1    1           75  single-ended    38046079
# 2     1_2    1          100  single-ended    32210747
# 3     1_2    1          100  single-ended    32231636
# 4     2_2    1          100  single-ended    18968586
#
#                                                  url  \
# 0  https://encode-public.s3.amazonaws.com/2018/06...
# 1  https://encode-public.s3.amazonaws.com/2018/06...
# 2  https://encode-public.s3.amazonaws.com/2022/01...
# 3  https://encode-public.s3.amazonaws.com/2022/01...
# 4  https://encode-public.s3.amazonaws.com/2022/01...
#
#                              md5sum     controls
# 0  596f29273326f236d21e9dcfbc7bde44  ENCSR020QUJ
# 1  872871049ed39779348841c516e36311  ENCSR020QUJ
# 2  a42e339580b9832afb0357dabda8b648  ENCSR239QGH
# 3  dd750faa1dec4db3bb1f27a83674df2c  ENCSR239QGH
# 4  8f94a92a30e42ad4ee2d32a3b8b3cb78  ENCSR239QGH

# %%
get_matching_control("ENCSR020QUJ")
# Out:
# 'ENCSR020QUJ'

# %%
df["matching_control"] = df.controls.map(get_matching_control)

# %%
df.head()
# Out:
#            exp          acc    target biosample           synonyms  biorep  \
# 0  ENCSR959XNY  ENCFF655BEL      MED1     HepG2  HepG2 cell,Hep-G2       2
# 1  ENCSR959XNY  ENCFF920MZO      MED1     HepG2  HepG2 cell,Hep-G2       1
# 2  ENCSR577YCO  ENCFF075LHW  ARHGAP35     HepG2  HepG2 cell,Hep-G2       1
# 3  ENCSR577YCO  ENCFF504PYF  ARHGAP35     HepG2  HepG2 cell,Hep-G2       1
# 4  ENCSR577YCO  ENCFF574DSC  ARHGAP35     HepG2  HepG2 cell,Hep-G2       2
#
#   techrep read  read_length      run_type  read_count  \
# 0     2_1    1           75  single-ended    40474263
# 1     1_1    1           75  single-ended    38046079
# 2     1_2    1          100  single-ended    32210747
# 3     1_2    1          100  single-ended    32231636
# 4     2_2    1          100  single-ended    18968586
#
#                                                  url  \
# 0  https://encode-public.s3.amazonaws.com/2018/06...
# 1  https://encode-public.s3.amazonaws.com/2018/06...
# 2  https://encode-public.s3.amazonaws.com/2022/01...
# 3  https://encode-public.s3.amazonaws.com/2022/01...
# 4  https://encode-public.s3.amazonaws.com/2022/01...
#
#                              md5sum     controls matching_control
# 0  596f29273326f236d21e9dcfbc7bde44  ENCSR020QUJ      ENCSR020QUJ
# 1  872871049ed39779348841c516e36311  ENCSR020QUJ      ENCSR020QUJ
# 2  a42e339580b9832afb0357dabda8b648  ENCSR239QGH      ENCSR239QGH
# 3  dd750faa1dec4db3bb1f27a83674df2c  ENCSR239QGH      ENCSR239QGH
# 4  8f94a92a30e42ad4ee2d32a3b8b3cb78  ENCSR239QGH      ENCSR239QGH

# %%
df[df["matching_control"] == None]
# Out:
# Empty DataFrame
# Columns: [exp, acc, target, biosample, synonyms, biorep, techrep, read, read_length, run_type, read_count, url, md5sum, controls, matching_control]
# Index: []

# %%
df[df["read_length"] >= 50]
# Out:
#               exp          acc    target         biosample  \
# 0     ENCSR959XNY  ENCFF655BEL      MED1             HepG2
# 1     ENCSR959XNY  ENCFF920MZO      MED1             HepG2
# 2     ENCSR577YCO  ENCFF075LHW  ARHGAP35             HepG2
# 3     ENCSR577YCO  ENCFF504PYF  ARHGAP35             HepG2
# 4     ENCSR577YCO  ENCFF574DSC  ARHGAP35             HepG2
# ...           ...          ...       ...               ...
# 9846  ENCSR236YGF  ENCFF730HKC      CTCF  transverse colon
# 9847  ENCSR775FSH  ENCFF533YAK   ZNF280B              K562
# 9848  ENCSR775FSH  ENCFF587EBW   ZNF280B              K562
# 9849  ENCSR775FSH  ENCFF084KUN   ZNF280B              K562
# 9850  ENCSR775FSH  ENCFF948VGD   ZNF280B              K562
#
#                          synonyms  biorep techrep read  read_length  \
# 0               HepG2 cell,Hep-G2       2     2_1    1           75
# 1               HepG2 cell,Hep-G2       1     1_1    1           75
# 2               HepG2 cell,Hep-G2       1     1_2    1          100
# 3               HepG2 cell,Hep-G2       1     1_2    1          100
# 4               HepG2 cell,Hep-G2       2     2_2    1          100
# ...                           ...     ...     ...  ...          ...
# 9846            colon transversum       1     1_2    1           76
# 9847   K562 cell,K-562,K-562 cell       1     1_1    1          100
# 9848   K562 cell,K-562,K-562 cell       2     2_1    2          100
# 9849   K562 cell,K-562,K-562 cell       1     1_1    2          100
# 9850   K562 cell,K-562,K-562 cell       2     2_1    1          100
#
#           run_type  read_count  \
# 0     single-ended    40474263
# 1     single-ended    38046079
# 2     single-ended    32210747
# 3     single-ended    32231636
# 4     single-ended    18968586
# ...            ...         ...
# 9846  single-ended    17309794
# 9847  paired-ended    36277628
# 9848  paired-ended    40551479
# 9849  paired-ended    36277628
# 9850  paired-ended    40551479
#
#                                                     url  \
# 0     https://encode-public.s3.amazonaws.com/2018/06...
# 1     https://encode-public.s3.amazonaws.com/2018/06...
# 2     https://encode-public.s3.amazonaws.com/2022/01...
# 3     https://encode-public.s3.amazonaws.com/2022/01...
# 4     https://encode-public.s3.amazonaws.com/2022/01...
# ...                                                 ...
# 9846  https://encode-public.s3.amazonaws.com/2017/12...
# 9847  https://encode-public.s3.amazonaws.com/2020/05...
# 9848  https://encode-public.s3.amazonaws.com/2020/05...
# 9849  https://encode-public.s3.amazonaws.com/2020/05...
# 9850  https://encode-public.s3.amazonaws.com/2020/05...
#
#                                 md5sum                 controls  \
# 0     596f29273326f236d21e9dcfbc7bde44              ENCSR020QUJ
# 1     872871049ed39779348841c516e36311              ENCSR020QUJ
# 2     a42e339580b9832afb0357dabda8b648              ENCSR239QGH
# 3     dd750faa1dec4db3bb1f27a83674df2c              ENCSR239QGH
# 4     8f94a92a30e42ad4ee2d32a3b8b3cb78              ENCSR239QGH
# ...                                ...                      ...
# 9846  df2c6191487927c534c9c4b1fddce94e              ENCSR828XQV
# 9847  c3e71c1f0a52db61fb452109c1508279  ENCSR502CWG,ENCSR275WKO
# 9848  00bd2b99ec66cd2238a3cbb67d304a6c  ENCSR502CWG,ENCSR275WKO
# 9849  dc457e356a75e080d38ae79397999c9c  ENCSR502CWG,ENCSR275WKO
# 9850  f668f2e57f158029a376b0e16c1078ce  ENCSR502CWG,ENCSR275WKO
#
#      matching_control
# 0         ENCSR020QUJ
# 1         ENCSR020QUJ
# 2         ENCSR239QGH
# 3         ENCSR239QGH
# 4         ENCSR239QGH
# ...               ...
# 9846      ENCSR828XQV
# 9847      ENCSR502CWG
# 9848      ENCSR502CWG
# 9849      ENCSR502CWG
# 9850      ENCSR502CWG
#
# [8188 rows x 15 columns]

# %%
df = df.drop(columns = ["controls"])

# %%
df = df.rename(columns={"matching_control" : "control"})

# %%
df.head()
# Out:
#            exp          acc    target biosample           synonyms  biorep  \
# 0  ENCSR959XNY  ENCFF655BEL      MED1     HepG2  HepG2 cell,Hep-G2       2
# 1  ENCSR959XNY  ENCFF920MZO      MED1     HepG2  HepG2 cell,Hep-G2       1
# 2  ENCSR577YCO  ENCFF075LHW  ARHGAP35     HepG2  HepG2 cell,Hep-G2       1
# 3  ENCSR577YCO  ENCFF504PYF  ARHGAP35     HepG2  HepG2 cell,Hep-G2       1
# 4  ENCSR577YCO  ENCFF574DSC  ARHGAP35     HepG2  HepG2 cell,Hep-G2       2
#
#   techrep read  read_length      run_type  read_count  \
# 0     2_1    1           75  single-ended    40474263
# 1     1_1    1           75  single-ended    38046079
# 2     1_2    1          100  single-ended    32210747
# 3     1_2    1          100  single-ended    32231636
# 4     2_2    1          100  single-ended    18968586
#
#                                                  url  \
# 0  https://encode-public.s3.amazonaws.com/2018/06...
# 1  https://encode-public.s3.amazonaws.com/2018/06...
# 2  https://encode-public.s3.amazonaws.com/2022/01...
# 3  https://encode-public.s3.amazonaws.com/2022/01...
# 4  https://encode-public.s3.amazonaws.com/2022/01...
#
#                              md5sum      control
# 0  596f29273326f236d21e9dcfbc7bde44  ENCSR020QUJ
# 1  872871049ed39779348841c516e36311  ENCSR020QUJ
# 2  a42e339580b9832afb0357dabda8b648  ENCSR239QGH
# 3  dd750faa1dec4db3bb1f27a83674df2c  ENCSR239QGH
# 4  8f94a92a30e42ad4ee2d32a3b8b3cb78  ENCSR239QGH

# %%
control_df.head()
# Out:
#            exp          acc   target              biosample  \
# 0  ENCSR501CEJ  ENCFF480KWL  Control                   K562
# 1  ENCSR501CEJ  ENCFF440JUL  Control                   K562
# 2  ENCSR631ESZ  ENCFF144AGB  Control  foreskin keratinocyte
# 3  ENCSR631ESZ  ENCFF699DOM  Control  foreskin keratinocyte
# 4  ENCSR631ESZ  ENCFF314CVE  Control  foreskin keratinocyte
#
#                       synonyms  biorep techrep read  read_length  \
# 0   K562 cell,K-562,K-562 cell       1     1_1    1          100
# 1   K562 cell,K-562,K-562 cell       1     1_1    2          100
# 2                                    1     1_1    1          101
# 3                                    1     1_1    2          101
# 4                                    2     2_1    1          101
#
#        run_type  read_count  \
# 0  paired-ended    40527474
# 1  paired-ended    40527474
# 2  paired-ended    53545193
# 3  paired-ended    53545193
# 4  paired-ended    55163711
#
#                                                  url  \
# 0  https://encode-public.s3.amazonaws.com/2019/01...
# 1  https://encode-public.s3.amazonaws.com/2019/01...
# 2  https://encode-public.s3.amazonaws.com/2016/12...
# 3  https://encode-public.s3.amazonaws.com/2016/12...
# 4  https://encode-public.s3.amazonaws.com/2016/12...
#
#                              md5sum       controls
# 0  2ed14357716c9c6984e253a203232b3f  input library
# 1  833b82da601d4bd440d036c355f46317  input library
# 2  12205cf8fe66fc7df336a89f014cba33  input library
# 3  522b0254a97c18e2878d4f253359919c  input library
# 4  946aa908c62e8c131f5ae7160c134001  input library

# %%
control_df = control_df.rename(columns = {"controls" : "control"})

# %%
control_df.head()
# Out:
#            exp          acc   target              biosample  \
# 0  ENCSR501CEJ  ENCFF480KWL  Control                   K562
# 1  ENCSR501CEJ  ENCFF440JUL  Control                   K562
# 2  ENCSR631ESZ  ENCFF144AGB  Control  foreskin keratinocyte
# 3  ENCSR631ESZ  ENCFF699DOM  Control  foreskin keratinocyte
# 4  ENCSR631ESZ  ENCFF314CVE  Control  foreskin keratinocyte
#
#                       synonyms  biorep techrep read  read_length  \
# 0   K562 cell,K-562,K-562 cell       1     1_1    1          100
# 1   K562 cell,K-562,K-562 cell       1     1_1    2          100
# 2                                    1     1_1    1          101
# 3                                    1     1_1    2          101
# 4                                    2     2_1    1          101
#
#        run_type  read_count  \
# 0  paired-ended    40527474
# 1  paired-ended    40527474
# 2  paired-ended    53545193
# 3  paired-ended    53545193
# 4  paired-ended    55163711
#
#                                                  url  \
# 0  https://encode-public.s3.amazonaws.com/2019/01...
# 1  https://encode-public.s3.amazonaws.com/2019/01...
# 2  https://encode-public.s3.amazonaws.com/2016/12...
# 3  https://encode-public.s3.amazonaws.com/2016/12...
# 4  https://encode-public.s3.amazonaws.com/2016/12...
#
#                              md5sum        control
# 0  2ed14357716c9c6984e253a203232b3f  input library
# 1  833b82da601d4bd440d036c355f46317  input library
# 2  12205cf8fe66fc7df336a89f014cba33  input library
# 3  522b0254a97c18e2878d4f253359919c  input library
# 4  946aa908c62e8c131f5ae7160c134001  input library

# %%
pd.concat([df, control_df]).to_csv("Metadata.txt", sep="\t", header=True, index=False)

# %%
# !cat Metadata.txt | head
# Out:
# exp	acc	target	biosample	synonyms	biorep	techrep	read	read_length	run_type	read_count	url	md5sum	control
# ENCSR959XNY	ENCFF655BEL	MED1	HepG2	HepG2 cell,Hep-G2	2	2_1	1	75	single-ended	40474263	https://encode-public.s3.amazonaws.com/2018/06/06/cfcbb186-586a-4aed-bf7f-03bdce6da3e8/ENCFF655BEL.fastq.gz	596f29273326f236d21e9dcfbc7bde44	ENCSR020QUJ
# ENCSR959XNY	ENCFF920MZO	MED1	HepG2	HepG2 cell,Hep-G2	1	1_1	1	75	single-ended	38046079	https://encode-public.s3.amazonaws.com/2018/06/06/f0bfba19-75e2-4e99-8788-67c583ec86c9/ENCFF920MZO.fastq.gz	872871049ed39779348841c516e36311	ENCSR020QUJ
# ENCSR577YCO	ENCFF075LHW	ARHGAP35	HepG2	HepG2 cell,Hep-G2	1	1_2	1	100	single-ended	32210747	https://encode-public.s3.amazonaws.com/2022/01/27/e698fa0d-06b9-4f07-8719-753ed23b6180/ENCFF075LHW.fastq.gz	a42e339580b9832afb0357dabda8b648	ENCSR239QGH
# ENCSR577YCO	ENCFF504PYF	ARHGAP35	HepG2	HepG2 cell,Hep-G2	1	1_2	1	100	single-ended	32231636	https://encode-public.s3.amazonaws.com/2022/01/27/548c070e-0fef-4230-9d71-a3a814f9f67e/ENCFF504PYF.fastq.gz	dd750faa1dec4db3bb1f27a83674df2c	ENCSR239QGH
# ENCSR577YCO	ENCFF574DSC	ARHGAP35	HepG2	HepG2 cell,Hep-G2	2	2_2	1	100	single-ended	18968586	https://encode-public.s3.amazonaws.com/2022/01/27/793c822e-212e-41eb-a79f-7c19304365ab/ENCFF574DSC.fastq.gz	8f94a92a30e42ad4ee2d32a3b8b3cb78	ENCSR239QGH
# ENCSR577YCO	ENCFF573AYA	ARHGAP35	HepG2	HepG2 cell,Hep-G2	2	2_2	1	100	single-ended	18837767	https://encode-public.s3.amazonaws.com/2022/01/27/fdce7791-750e-4489-ab0a-60177f441b20/ENCFF573AYA.fastq.gz	b92da1085eff4b09be1f101cd9a2d0e7	ENCSR239QGH
# ENCSR924LSO	ENCFF922FCP	E2F4	HepG2	HepG2 cell,Hep-G2	1	1_1	1	75	single-ended	31617494	https://encode-public.s3.amazonaws.com/2018/05/22/fcc11cc4-54e6-42ac-938b-a345a60502c2/ENCFF922FCP.fastq.gz	6120ebbdfb1f289df9860b3e70021b10	ENCSR020QUJ
# ENCSR924LSO	ENCFF303PBY	E2F4	HepG2	HepG2 cell,Hep-G2	2	2_1	1	75	single-ended	46321877	https://encode-public.s3.amazonaws.com/2018/05/22/51374389-8b03-4518-9e88-1be8fbfe8cc8/ENCFF303PBY.fastq.gz	376e6ab22ba474c69fc8d5dbb3eb66bd	ENCSR020QUJ
# ENCSR942XQI	ENCFF989YGA	RAD21	K562	 K562 cell,K-562,K-562 cell	1	1_1	1	100	paired-ended	54054725	https://encode-public.s3.amazonaws.com/2021/03/21/9c972711-4fde-4938-b0af-196ab6d853cf/ENCFF989YGA.fastq.gz	8fd5972bbecd7b111cfecde6d1263b47	ENCSR085CJF
# cat: write error: Broken pipe

# %%
pd.concat([df, control_df]).exp.unique().shape
# Out:
# (4269,)

# %%
TFs = df.target.unique().tolist()
ZNF_TFs = df[df["target"].str.contains("ZNF")].target.unique().tolist()
print("There are {} ZNF TFs".format(len(ZNF_TFs)))
TFs_of_interest = ZNF_TFs + ["CTCF", "REST", "MAX"]
# Out:
# There are 306 ZNF TFs

# %%
df['read_length'].unique()
# Out:
# array([ 75, 100,  76, 101,  51, 151,  36,  50,  32,  40,  30,  34,  35,
#         27,  28,  37,  25,  33,  29,  74])

# %%
readcounts = metadata.groupby("exp")["read_count"].sum().to_dict()
